# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals

import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# %matplotlib inline

import seaborn as sns
sns.set(color_codes=True)

# %%
data = pd.DataFrame()

# %%
data = data.from_csv('assets.csv')
data
# Out:
#                   name       amount  \
# 0             GiveBack    100000000
# 1           BLACKPEARL    250000000
# 2               bxcoin     10000000
# 3          UpGradeCoin       692500
# 4                 GIVE   1000000000
# 5                 APCY      5000000
# 6              AusCoin       800000
# 7          Andrynowski     21000000
# 8            Prestoken  10000000000
# 9            McDonalds    100000000
# 10          TenX (PAY)    205218256
# 11      1ST FirstBlood     93468691
# 12     Ray Block Token      1000000
# 13                BBRT    500000000
# 14                Wave     10000000
# 15           RewardMob    250000000
# 16                UBIT  10000000000
# 17          XRP Ripple   9994523265
# 18             SexCoin     69000000
# 19              InGold       100000
# 20        SEEDWEEDCOIN      1000000
# 21           Repicoins      2000000
# 22             gdlcoin    100000000
# 23      fuck off token      1000000
# 24           ClienCoin    100000000
# ...

# %%
import csv
data.to_csv('assets_qu.csv', encoding='utf-8', index=False)

# %%
data3 = pd.DataFrame().from_csv('assets_qu.csv')
data3
# Out:
#                        amount  \
# name
# GiveBack            100000000
# BLACKPEARL          250000000
# bxcoin               10000000
# UpGradeCoin            692500
# GIVE               1000000000
# APCY                  5000000
# AusCoin                800000
# Andrynowski          21000000
# Prestoken         10000000000
# McDonalds           100000000
# TenX (PAY)          205218256
# 1ST FirstBlood       93468691
# Ray Block Token       1000000
# BBRT                500000000
# Wave                 10000000
# RewardMob           250000000
# UBIT              10000000000
# XRP Ripple         9994523265
# SexCoin              69000000
# InGold                 100000
# SEEDWEEDCOIN          1000000
# Repicoins             2000000
# gdlcoin             100000000
# fuck off token        1000000
# ClienCoin           100000000
# Pollockoin           19121956
# Basbas               10000000
# LeonidCoins           1000000
# CREDIT             1000000000
# ...

# %%
data.to_json('assets_qu.json')
